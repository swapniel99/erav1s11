# %% [markdown]
# <a href="https://colab.research.google.com/github/swapniel99/erav1s11/blob/main/S11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/swapniel99/epoch.git
# %pushd epoch
# !git pull
# !pip install -qr requirements.txt
# %ls
# %popd
# Out:
# fatal: destination path 'epoch' already exists and is not an empty directory.
# /content/epoch
# Already up to date.
# assets/    __init__.py  models/       README.md         utils/
# datasets/  main.py      __pycache__/  requirements.txt
# /content
# popd -> /content

# %%
from epoch.main import *
# Out:
# /usr/local/lib/python3.10/dist-packages/torch_lr_finder/lr_finder.py:5: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# Device Selected: cuda
# Files already downloaded and verified
# Files already downloaded and verified

# %%
cifar10.show_examples()
# Out:
# /content/epoch/datasets/generic.py:64: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   result = torch.tensor(tensor, requires_grad=False)

# %%
print_summary(model)
# Out:
# ...
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Param %
# ...
# ResNet                                   [32, 3, 32, 32]           [32, 10]                  --                             --
# ├─Conv2d: 1-1                            [32, 3, 32, 32]           [32, 64, 32, 32]          1,728                       0.02%
# ├─BatchNorm2d: 1-2                       [32, 64, 32, 32]          [32, 64, 32, 32]          128                         0.00%
# ├─Sequential: 1-3                        [32, 64, 32, 32]          [32, 64, 32, 32]          --                             --
# │    └─BasicBlock: 2-1                   [32, 64, 32, 32]          [32, 64, 32, 32]          --                             --
# │    │    └─Conv2d: 3-1                  [32, 64, 32, 32]          [32, 64, 32, 32]          36,864                      0.33%
# ...

# %%
experiment = create_experiment(model, cifar10, criterion='crossentropy', epochs=20, scheduler='one_cycle')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 2.42E-03

# %%
experiment.execute()
# Out:
# Epoch: 1
# Train: Average Loss: 1.6903, Accuracy: 37.43 LR: 0.0005031413832510582: 100%|██████████| 1563/1563 [00:59<00:00, 26.07it/s]
# Test:  Average loss: 1.2917, Accuracy: 53.02
# Epoch: 2
# Train: Average Loss: 1.2129, Accuracy: 56.53 LR: 0.0009823881036368888: 100%|██████████| 1563/1563 [01:01<00:00, 25.32it/s]
# Test:  Average loss: 1.0066, Accuracy: 63.91
# Epoch: 3
# Train: Average Loss: 0.9770, Accuracy: 65.66 LR: 0.00146163482402272: 100%|██████████| 1563/1563 [01:01<00:00, 25.45it/s]
# Test:  Average loss: 0.8571, Accuracy: 70.47
# Epoch: 4
# Train: Average Loss: 0.8307, Accuracy: 70.87 LR: 0.0019408815444085506: 100%|██████████| 1563/1563 [01:01<00:00, 25.61it/s]
# Test:  Average loss: 0.6545, Accuracy: 77.49
# Epoch: 5
# Train: Average Loss: 0.7385, Accuracy: 74.36 LR: 0.0024201282647943814: 100%|██████████| 1563/1563 [01:00<00:00, 25.68it/s]
# Test:  Average loss: 0.5874, Accuracy: 79.74
# Epoch: 6
# ...

# %%
experiment.train.plot_stats()

# %%
experiment.test.plot_stats()

# %%
experiment.show_incorrect()
# Out:
# Test:  Average loss: 0.2524, Accuracy: 91.49

# %%
experiment.show_incorrect(cams=True)
